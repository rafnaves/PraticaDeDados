# %%
import pandas as pd

# %% [markdown]
# ## Criar DataFrame com Base nos Datasets

# %%
# Carregar Dataframe de Clientes (Customer)

df_customers = pd.read_csv('/home/rafnaves/estudos/rocketseat/IA/eda/datasets/churn_customers.csv')

# %%
# Mostrar 5 primeiros registros
df_customers.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female              0     Yes         No
# 1  5575-GNVDE    Male              0      No         No
# 2  3668-QPYBK    Male              0      No         No
# 3  7795-CFOCW    Male              0      No         No
# 4  9237-HQITU  Female              0      No         No

# %%
# Mostrar 5 ultimos registros
df_customers.tail(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents
# 7038  6840-RESVB    Male              0     Yes        Yes
# 7039  2234-XADUH  Female              0     Yes        Yes
# 7040  4801-JZAZL  Female              0     Yes        Yes
# 7041  8361-LTMKD    Male              1     Yes         No
# 7042  3186-AJIEK    Male              0      No         No

# %%
# Mostrar Estrutura / Schema do DataFrame
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
# Dataframe de serviços (services)
# Carregar Dataframe de Clientes (Customer)

df_services = pd.read_csv('/home/rafnaves/estudos/rocketseat/IA/eda/datasets/churn_services.csv')
df_services.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   PhoneService      7043 non-null   object
#  2   MultipleLines     7043 non-null   object
#  3   InternetService   7043 non-null   object
#  4   OnlineSecurity    7043 non-null   object
#  5   OnlineBackup      7043 non-null   object
#  6   DeviceProtection  7043 non-null   object
#  7   TechSupport       7043 non-null   object
#  8   StreamingTV       7043 non-null   object
#  9   StreamingMovies   7043 non-null   object
# dtypes: object(10)
# memory usage: 550.4+ KB

# %%
df_services.head(5)
# Out:
#    customerID PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0  7590-VHVEG           No  No phone service             DSL             No
# 1  5575-GNVDE          Yes                No             DSL            Yes
# 2  3668-QPYBK          Yes                No             DSL            Yes
# 3  7795-CFOCW           No  No phone service             DSL            Yes
# 4  9237-HQITU          Yes                No     Fiber optic             No
#
#   OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies
# 0          Yes               No          No          No              No
# 1           No              Yes          No          No              No
# 2          Yes               No          No          No              No
# 3           No              Yes         Yes          No              No
# 4           No               No          No          No              No

# %%
df_services.tail(5)
# Out:
#       customerID PhoneService     MultipleLines InternetService  \
# 7038  6840-RESVB          Yes               Yes             DSL
# 7039  2234-XADUH          Yes               Yes     Fiber optic
# 7040  4801-JZAZL           No  No phone service             DSL
# 7041  8361-LTMKD          Yes               Yes     Fiber optic
# 7042  3186-AJIEK          Yes                No     Fiber optic
#
#      OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 7038            Yes           No              Yes         Yes         Yes
# 7039             No          Yes              Yes          No         Yes
# 7040            Yes           No               No          No          No
# 7041             No           No               No          No          No
# 7042            Yes           No              Yes         Yes         Yes
#
#      StreamingMovies
# 7038             Yes
# 7039             Yes
# 7040              No
# 7041              No
# 7042             Yes

# %%
# Carregar DataFrame de Contratos (contracts)
df_contracts = pd.read_csv('/home/rafnaves/estudos/rocketseat/IA/eda/datasets/churn_contracts.csv')
df_contracts.head(5)
# Out:
#    customerID  tenure        Contract PaperlessBilling  \
# 0  7590-VHVEG       1  Month-to-month              Yes
# 1  5575-GNVDE      34        One year               No
# 2  3668-QPYBK       2  Month-to-month              Yes
# 3  7795-CFOCW      45        One year               No
# 4  9237-HQITU       2  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges TotalCharges Churn
# 0           Electronic check           29.85        29.85    No
# 1               Mailed check           56.95       1889.5    No
# 2               Mailed check           53.85       108.15   Yes
# 3  Bank transfer (automatic)           42.30      1840.75    No
# 4           Electronic check           70.70       151.65   Yes

# %%
df_contracts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   tenure            7043 non-null   int64
#  2   Contract          7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7043 non-null   object
#  7   Churn             7043 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 440.3+ KB

# %%
df_contracts.tail(5)
# Out:
#       customerID  tenure        Contract PaperlessBilling  \
# 7038  6840-RESVB      24        One year              Yes
# 7039  2234-XADUH      72        One year              Yes
# 7040  4801-JZAZL      11  Month-to-month              Yes
# 7041  8361-LTMKD       4  Month-to-month              Yes
# 7042  3186-AJIEK      66        Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 7038               Mailed check           84.80       1990.5    No
# 7039    Credit card (automatic)          103.20       7362.9    No
# 7040           Electronic check           29.60       346.45    No
# 7041               Mailed check           74.40        306.6   Yes
# 7042  Bank transfer (automatic)          105.65       6844.5    No

# %% [markdown]
# ## Transformação de Dados

# %%
# Transformar coluna TotalCharges de String para Float - Abordagem 1 com astype
df_contracts.TotalCharges = df_contracts.TotalCharges.astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 # Transformar coluna TotalCharges de String para Float - Abordagem 1 com astype
# ----> 2 df_contracts.TotalCharges = df_contracts.TotalCharges.astype(float)
#
# File ~/.pyenv/versions/IA/lib/python3.11/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# ...

# %%
# Transformar coluna TotalCharges de String para Float - abordagem 2 (to_numeric)
df_contracts.TotalCharges = pd.to_numeric(df_contracts.TotalCharges)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File lib.pyx:2391, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Transformar coluna TotalCharges de String para Float - abordagem 2 (to_numeric)
# ----> 2 df_contracts.TotalCharges = pd.to_numeric(df_contracts.TotalCharges)
#
# File ~/.pyenv/versions/IA/lib/python3.11/site-packages/pandas/core/tools/numeric.py:232, in to_numeric(arg, errors, downcast, dtype_backend)
#     230 coerce_numeric = errors not in ("ignore", "raise")
#     231 try:
# --> 232     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]
#     233         values,
#     234         set(),
# ...

# %%
# Transformar coluna TotalCharges de String para Float - abordagem 3 (to_numeric com coerce)

df_contracts.TotalCharges = pd.to_numeric(df_contracts.TotalCharges, errors='coerce')

# %%
df_contracts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   tenure            7043 non-null   int64
#  2   Contract          7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7032 non-null   float64
#  7   Churn             7043 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 440.3+ KB

# %% [markdown]
# Após a transfomarção de TotalCharges para numerics, a coluna passou a ter 11 valores ausentes

# %% [markdown]
# ## Renomear Colunas

# %%
# Renomear coluna no DataFrame, usando rename e dicionario
df_customers.rename(columns={'SeniorCitizen':'Above65yo'})
# Out:
#       customerID  gender  Above65yo Partner Dependents
# 0     7590-VHVEG  Female          0     Yes         No
# 1     5575-GNVDE    Male          0      No         No
# 2     3668-QPYBK    Male          0      No         No
# 3     7795-CFOCW    Male          0      No         No
# 4     9237-HQITU  Female          0      No         No
# ...          ...     ...        ...     ...        ...
# 7038  6840-RESVB    Male          0     Yes        Yes
# 7039  2234-XADUH  Female          0     Yes        Yes
# 7040  4801-JZAZL  Female          0     Yes        Yes
# 7041  8361-LTMKD    Male          1     Yes         No
# 7042  3186-AJIEK    Male          0      No         No
#
# [7043 rows x 5 columns]

# %%
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
# Criar um DataFrame com Base nas colunas renomeadas
df_customers_renamed = df_customers.rename(columns={'SeniorCitizen':'Above65yo'})
df_customers_renamed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7043 non-null   object
#  1   gender      7043 non-null   object
#  2   Above65yo   7043 non-null   int64
#  3   Partner     7043 non-null   object
#  4   Dependents  7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
# Aplicar o resultado do rename no proprio DataFrame
df_customers.rename(columns={'SeniorCitizen':'Above65yo'}, inplace=True)
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7043 non-null   object
#  1   gender      7043 non-null   object
#  2   Above65yo   7043 non-null   int64
#  3   Partner     7043 non-null   object
#  4   Dependents  7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
# Rename usando Lista - Modificar todos os nomes de colunas
df_customers.columns = ['IDCliente', 'Genero','Mais65anos','TemParceiro','TemDependentes']
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   IDCliente       7043 non-null   object
#  1   Genero          7043 non-null   object
#  2   Mais65anos      7043 non-null   int64
#  3   TemParceiro     7043 non-null   object
#  4   TemDependentes  7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %% [markdown]
# ## Unificar DataFrames de Costumes, Services e Contracts

# %%
# Contar quantidade de registros por DataFrame
len(df_customers)
# Out:
# 7043

# %%
len(df_services)
# Out:
# 7043

# %%
len(df_contracts)
# Out:
# 7043

# %%
# Renomear Colunas
df_services.rename(columns={'customerID': 'IDCliente'},inplace=True)
df_services.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   PhoneService      7043 non-null   object
#  2   MultipleLines     7043 non-null   object
#  3   InternetService   7043 non-null   object
#  4   OnlineSecurity    7043 non-null   object
#  5   OnlineBackup      7043 non-null   object
#  6   DeviceProtection  7043 non-null   object
#  7   TechSupport       7043 non-null   object
#  8   StreamingTV       7043 non-null   object
#  9   StreamingMovies   7043 non-null   object
# dtypes: object(10)
# memory usage: 550.4+ KB

# %%
# Unificando DataFrame de customer com services, criando um terceiro DataFrame
df_temp = df_customers.merge(df_services, on=['IDCliente'])

# %%
# Mostrar dataframe temp
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   Genero            7043 non-null   object
#  2   Mais65anos        7043 non-null   int64
#  3   TemParceiro       7043 non-null   object
#  4   TemDependentes    7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
# dtypes: int64(1), object(13)
# memory usage: 770.5+ KB

# %%
df_temp.head(5)
# Out:
#     IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0  7590-VHVEG  Female           0         Yes             No           No
# 1  5575-GNVDE    Male           0          No             No          Yes
# 2  3668-QPYBK    Male           0          No             No          Yes
# 3  7795-CFOCW    Male           0          No             No           No
# 4  9237-HQITU  Female           0          No             No          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies
# 0               No          No          No              No
# ...

# %%
# Merge com nomes de coluna diferentes porem conteudo iguals
df_churn_temp = df_temp.merge(df_contracts, left_on=['IDCliente'], right_on=['customerID'])

# %%
df_churn_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   Genero            7043 non-null   object
#  2   Mais65anos        7043 non-null   int64
#  3   TemParceiro       7043 non-null   object
#  4   TemDependentes    7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  customerID        7043 non-null   object
#  15  tenure            7043 non-null   int64
# ...

# %%
# Unificar os tres dataframes de uma vez, com colunas de nomes diferentes
df_churn = df_customers.merge(df_services, on=['IDCliente']).merge(df_contracts, left_on=['IDCliente'], right_on=['customerID'])
df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   Genero            7043 non-null   object
#  2   Mais65anos        7043 non-null   int64
#  3   TemParceiro       7043 non-null   object
#  4   TemDependentes    7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  customerID        7043 non-null   object
#  15  tenure            7043 non-null   int64
# ...

# %%
# Removendo coluna duplicada
df_churn.drop(['customerID'], axis=1, inplace=True)
df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   Genero            7043 non-null   object
#  2   Mais65anos        7043 non-null   int64
#  3   TemParceiro       7043 non-null   object
#  4   TemDependentes    7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  tenure            7043 non-null   int64
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# ## Detecção de Valores ausentes

# %%
## Detecção de Valores ausentes em todas colunas de um DataFrame

df_churn.isna().sum()
# Out:
# IDCliente            0
# Genero               0
# Mais65anos           0
# TemParceiro          0
# TemDependentes       0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# tenure               0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
# Detectar valores ausentes em uma coluna
df_churn.TotalCharges.isna().sum()
# Out:
# np.int64(11)

# %%
# Quantas linhas tem pelo menos 1 coluna com valor ausente
df_churn[df_churn.isna().any(axis=1)]
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 488   4472-LVYGI  Female           0         Yes            Yes           No
# 753   3115-CZMZD    Male           0          No            Yes          Yes
# 936   5709-LVOEQ  Female           0         Yes            Yes          Yes
# 1082  4367-NUYAO    Male           0         Yes            Yes          Yes
# 1340  1371-DWPAZ  Female           0         Yes            Yes           No
# 3331  7644-OMVMY    Male           0         Yes            Yes          Yes
# 3826  3213-VVOLG    Male           0         Yes            Yes          Yes
# 4380  2520-SGTTA  Female           0         Yes            Yes          Yes
# 5218  2923-ARZLG    Male           0         Yes            Yes          Yes
# 6670  4075-WKNIU  Female           0         Yes            Yes          Yes
# 6754  2775-SEFEE    Male           0          No            Yes          Yes
#
# ...

# %%
# Quantas colunas tem pelo menos 1 valor ausente
df_churn.isna().any(axis=0).sum()
# Out:
# np.int64(1)

# %% [markdown]
# ## Remover valores ausentes

# %%
# Remover de forma direta a coluna
df_churn.drop(columns=['TotalCharges'], axis=1)
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %%
# Remover colunas com valores ausentes
df_churn.dropna(axis=1)
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %%
# Remover colunas com todos os valores ausentes
df_churn.dropna(axis=1, how='all')
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %%
# Remover linhas com valores ausentes
df_churn.dropna(axis=0)
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %%
# Remover linhas com todos os valores ausentes
df_churn.dropna(axis=0, how='all')
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %% [markdown]
# ## Inputação de Valores Ausentes

# %%
# Preencher todos os valores ausentes por 0
df_churn.fillna(0)
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %%
# Preencher valores padrão conforme a coluna
df_churn.fillna(value={'TotalCharges':0, 'Genero': 'Não Declarado'})
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %%
# Prencher todos os valores ausentes de uma coluna com a media
media_TotalCharges = df_churn.TotalCharges.mean()
df_churn.fillna(value={'TotalCharges':media_TotalCharges})
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %% [markdown]
# ## Analise Univariada

# %% [markdown]
# - a faixa etaria do cliente tem uma forte associação associada com o churn
#
# - Um cliente com menos de 6 meses de contrato é mais propenso ao churn
#
# - cliente com contrato mensal é mais pronpenso ao churn

# %%
# Contar clientes usando a variaval Churn como referencia
df_churn.Churn.value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
# Identificar distribuição usando porcentagem
df_churn.Churn.value_counts(normalize=True)
# Out:
# Churn
# No     0.73463
# Yes    0.26537
# Name: proportion, dtype: float64

# %%
# Como identificar valores possiveis (unicos) numa variavel do dataframe
df_churn.Churn.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
# Plot distribuição Churn (quantidade)
ax = df_churn.Churn.value_counts().plot.bar()

ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '5174'), Text(0, 0, '1869')]

# %%
# Quais são os tipos de contrato
df_churn.Contract.unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
# Plot distribuição Contrato (quantidade)
ax = df_churn.Contract.value_counts().plot.bar()

ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '3875'), Text(0, 0, '1695'), Text(0, 0, '1473')]

# %%
# Histograma do tempo de contrato
df_churn.tenure.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# A variavel tempo de contrato (ternure) não apresenta uma distribuição normal
# a maioria dos valores se concetram nos extremos, ou seja contratos com poucos meses de ativação e contratos longos, acima dos 65 meses.

# %%
# Histograma do Monthly Charges
df_churn.MonthlyCharges.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Medidas de Posição - Media tempo de contrato
df_churn.tenure.mean()
# Out:
# np.float64(32.37114865824223)

# %%
# Medidas de Posição - Mediana
df_churn.tenure.median()
# Out:
# np.float64(29.0)

# %%
# Medidas de Posição - Moda
df_churn.tenure.mode()
# Out:
# 0    1
# Name: tenure, dtype: int64

# %%
# Medidas de dipersão - desvio Padrão tempo de contrato
df_churn.tenure.std()
# Out:
# np.float64(24.55948102309446)

# %%
# Medidas de dipersão - Coeficiente de variação
df_churn.tenure.std() / df_churn.tenure.mean() * 100
# Out:
# np.float64(75.86842617906674)

# %%
# Quantos Clientes possuem 1 mes de contrato - Filtro
len(df_churn[(df_churn.tenure==1)])
# Out:
# 613

# %%
# Quantos clientes de 1 mes de contrato representam percentualmente
len(df_churn[(df_churn.tenure==1)]) / len(df_churn) * 100
# Out:
# 8.70367741019452

# %%
# Quantos clientes possuem entre 1 e 6 meses de contrato
len (df_churn[(df_churn.tenure>=1) & (df_churn.tenure<=6)])
# Out:
# 1470

# %%
df_churn.groupby(['tenure'])['tenure'].count().sort_values(ascending=False)
# Out:
# tenure
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: tenure, Length: 73, dtype: int64

# %%
df_churn.groupby(['tenure'])['tenure'].count().sort_values().plot.barh(figsize = (20, 20))
# Out:
# <Axes: ylabel='tenure'>

# %% [markdown]
# ## Analise Bivariada

# %%
# Hipotese: Clientes com contrato do tipo mensal são mais propensos ao churn
# Construir tabela de contigencia entre tipo de contrato e churn

pd.crosstab(df_churn.Churn, df_churn.Contract, margins=True)
# Out:
# Contract  Month-to-month  One year  Two year   All
# Churn
# No                  2220      1307      1647  5174
# Yes                 1655       166        48  1869
# All                 3875      1473      1695  7043

# %%
# Contruir Tabela de Contigencia entre Tipo de Contrato e Churn - proporção
pd.crosstab(df_churn.Churn, df_churn.Contract, margins=True, normalize='index')
# Out:
# Contract  Month-to-month  One year  Two year
# Churn
# No              0.429068  0.252609  0.318322
# Yes             0.885500  0.088818  0.025682
# All             0.550192  0.209144  0.240664

# %% [markdown]
# Considerando o publico total, os clientes de contrato mensal representam 55%. porem se consideramos apenas os clientes que abandonaram o serviço, 88% tinham contrato mensal mes.
# Desta forma, podemos afirmar que há uma correlação entre i tipo de contrato mensal e de abandono

# %%
# avaliar correlação entre duas variaveis categoricas

# Teste de hipotese chamado chi-square ou qui-quadrado de pearson
# num teste de hipotese, duas hipoteses são formuladas:
# H0 (hipotese nula): as duas variaveis são idependentes
# h1 (hipotese complementar): as duas não são idependentes

# o teste confirma ou recusa a hipotese nula
#  quando a probabilidade de observarmos h0 é inferior a 0.05 (p-value) recusamos a hipotese nula

# %%
# df da crosstab (sem totais)
df_crosstab_churn_contract = pd.crosstab(df_churn.Churn, df_churn.Contract)

# %%
# Calcular os scores e p-values
from scipy.stats import chi2
from scipy.stats import chi2_contingency

# %%
# Tupla = Lista imutavel
chi_scores_churn_contract = chi2_contingency(df_crosstab_churn_contract)

# %%
chi_scores_churn_contract
# Out:
# Chi2ContingencyResult(statistic=np.float64(1184.5965720837926), pvalue=np.float64(5.863038300673391e-258), dof=2, expected_freq=array([[2846.69175067, 1082.11018032, 1245.198069  ],
#        [1028.30824933,  390.88981968,  449.801931  ]]))

# %%
scores_churn_contract = pd.Series(chi_scores_churn_contract[0])

# %%
pvalues_churn_contract = pd.Series(chi_scores_churn_contract[1])

# %%
# apresentar numeros com decimais sem a notação cientifica
pd.set_option('display.float_format', lambda x: '%.15f' %x)

# %%
# Criar dataframe com os resultados
df_chi_scores_churn_contract = pd.DataFrame({'qui2': scores_churn_contract, 'p_value': pvalues_churn_contract})

# %%
df_chi_scores_churn_contract
# Out:
#                   qui2           p_value
# 0 1184.596572083792580 0.000000000000000

# %% [markdown]
# Conforme Teste estatistico (chi square), o pvalue <= 0.05, desta forma rejeitamos a hipotese nula, ou seja as variaveis não são idependentes. pelo qui2 alto, podemos afirmar que há uma forte correlação

# %%
# Avaliar a correlação entre uma variaval qualitativa q quantitativa
# Usar o mesmo teste de chi-square, mas transformar a variavel quantitativa em qualitativa
# hipotese cliente com menos de 6 meses de contrato é mais propenso ao churn

# criar uma coluna nova no DataFrame com base numa condição de outra coluna
# coluna = 'TempoMenor6Meses'
import numpy as np

# %%
# criar coluna nova
df_churn['TempoMenor6Meses'] = np.where(df_churn.tenure<6, 'Yes', 'no')

# %%
df_churn.head(5)
# Out:
#     IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0  7590-VHVEG  Female           0         Yes             No           No
# 1  5575-GNVDE    Male           0          No             No          Yes
# 2  3668-QPYBK    Male           0          No             No          Yes
# 3  7795-CFOCW    Male           0          No             No           No
# 4  9237-HQITU  Female           0          No             No          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 0  No phone service             DSL             No          Yes  ...
# 1                No             DSL            Yes           No  ...
# 2                No             DSL            Yes          Yes  ...
# 3  No phone service             DSL            Yes           No  ...
# 4                No     Fiber optic             No           No  ...
#
#   StreamingTV StreamingMovies tenure        Contract  PaperlessBilling  \
# ...

# %%
df_crosstab_churn_tenure = pd.crosstab(df_churn.Churn, df_churn.TempoMenor6Meses)

# %%
#calcular os scores
chi_scores_churn_tenure = chi2_contingency(df_crosstab_churn_tenure)

# %%
scores_churn_tenure = pd.Series(chi_scores_churn_tenure[0])
pvalues_churn_tenure = pd.Series(chi_scores_churn_tenure[1])

# %%
df_chi_scores_churn_tenure = pd.DataFrame({'Qui2': scores_churn_tenure, 'p-value':pvalues_churn_tenure})
df_chi_scores_churn_tenure
# Out:
#                  Qui2           p-value
# 0 669.721615828710355 0.000000000000000

# %% [markdown]
# Como o p-value <= 0.5, rejeitamos a h0, ou seja as variaveis não são idependentes
# - a correlação entre churn e tempo de contrato <6 meses é menor que a correlação entre churn e tipo de contrato.

# %%
# Correlação de duas variaveis numericas
# quanto mais tempo de contrato, maior o valor pago

# Correlação entre duas varveis numerias - pearson
df_churn.tenure.corr(df_churn.TotalCharges)
# Out:
# np.float64(0.825880460933202)

# %%
# Correlação de duas variaveis numericas
# quanto mais tempo de contrato, maior o valor pago

# Correlação entre duas varveis numerias - sparmen
df_churn.tenure.corr(df_churn.TotalCharges, method='spearman')
# Out:
# np.float64(0.8891770805365491)

# %%
# plot scatter entre tenure e total charges
# grafico de dispersão
df_churn.plot.scatter(x='tenure', y='TotalCharges')
# Out:
# <Axes: xlabel='tenure', ylabel='TotalCharges'>

# %%
# Validar se a faixa etaria do cliente tem uma forte associação com churn
df_churn.head()
# Out:
#     IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0  7590-VHVEG  Female           0         Yes             No           No
# 1  5575-GNVDE    Male           0          No             No          Yes
# 2  3668-QPYBK    Male           0          No             No          Yes
# 3  7795-CFOCW    Male           0          No             No           No
# 4  9237-HQITU  Female           0          No             No          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 0  No phone service             DSL             No          Yes  ...
# 1                No             DSL            Yes           No  ...
# 2                No             DSL            Yes          Yes  ...
# 3  No phone service             DSL            Yes           No  ...
# 4                No     Fiber optic             No           No  ...
#
#   StreamingTV StreamingMovies tenure        Contract  PaperlessBilling  \
# ...

# %%
# avaliar correlação entre duas variaveis categoricas

# Teste de hipotese chamado chi-square ou qui-quadrado de pearson
# num teste de hipotese, duas hipoteses são formuladas:
# H0 (hipotese nula): as duas variaveis são idependentes
# h1 (hipotese complementar): as duas não são idependentes

# o teste confirma ou recusa a hipotese nula
#  quando a probabilidade de observarmos h0 é inferior a 0.05 (p-value) recusamos a hipotese nula
# a faixa etaria do cliente tem associação com churn?

# Criando a tabela de contingência 
tabela_contingencia = pd.crosstab(df_churn['Mais65anos'], df_churn['Churn'])

print(tabela_contingencia)
# Out:
# Churn         No   Yes
# Mais65anos
# 0           4508  1393
# 1            666   476

# %%
chi2, p, dof, expected = chi2_contingency(tabela_contingencia)

print(f"Qui-quadrado: {chi2}")
print(f"Valor-p: {p}")
# Out:
# Qui-quadrado: 159.42630036838742
# Valor-p: 1.510066805092378e-36

# %% [markdown]
# O valor-p (p-value) é 1.51e-36, ou seja, quase zero, muito menor que 0.05.
#
# Isso significa que há uma associação estatisticamente significativa entre idade acima de 65 anos e churn. Em outras palavras, a idade do cliente influencia o churn de forma relevante.

# %%
# o tipo de contrato influencia?
# Criando a tabela de contingência 
tabela_contingencia = pd.crosstab(df_churn['Contract'], df_churn['Churn'])

print(tabela_contingencia)
# Out:
# Churn             No   Yes
# Contract
# Month-to-month  2220  1655
# One year        1307   166
# Two year        1647    48

# %%
chi2, p, dof, expected = chi2_contingency(tabela_contingencia)

print(f"Qui-quadrado: {chi2}")
print(f"Valor-p: {p}")
# Out:
# Qui-quadrado: 1184.5965720837926
# Valor-p: 5.863038300673391e-258

# %% [markdown]
# ## Re-Teste

# %%
# avaliar correlação entre duas variaveis categoricas
# a idade influencia no churn?
# df da crosstab (sem totais)
df_crosstab_churn_Mais65anos = pd.crosstab(df_churn.Churn, df_churn.Mais65anos)

# %%
# Tupla = Lista imutavel
chi_scores_churn_Mais65anos = chi2_contingency(df_crosstab_churn_Mais65anos)
chi_scores_churn_contract
# Out:
# Chi2ContingencyResult(statistic=np.float64(1184.5965720837926), pvalue=np.float64(5.863038300673391e-258), dof=2, expected_freq=array([[2846.69175067, 1082.11018032, 1245.198069  ],
#        [1028.30824933,  390.88981968,  449.801931  ]]))

# %%
scores_churn_Mais65anos= pd.Series(chi_scores_churn_Mais65anos[0])

# %%
pvalues_churn_Mais65anos = pd.Series(chi_scores_churn_Mais65anos[1])

# %%
# Criar dataframe com os resultados
df_chi_scores_churn_Mais65anos = pd.DataFrame({'qui2': scores_churn_Mais65anos, 'p_value': pvalues_churn_Mais65anos})

# %%
df_chi_scores_churn_Mais65anos
# Out:
#                  qui2           p_value
# 0 159.426300368387416 0.000000000000000

# %% [markdown]
# Conforme Teste estatistico (chi square), o pvalue <= 0.05, desta forma rejeitamos a hipotese nula, ou seja as variaveis não são idependentes. pelo qui2 alto, podemos afirmar que há uma forte correlação

# %%
# Month-to-month influencia no cancelamento do contrato?
# Contract -> qualitativa
# tenure -> qualitativa

# %%
# criar coluna nova
df_churn['MesAmes'] = np.where(df_churn.Contract=='Month-to-month', 'Yes', 'no')

# %%
df_churn.head(5)
# Out:
#     IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0  7590-VHVEG  Female           0         Yes             No           No
# 1  5575-GNVDE    Male           0          No             No          Yes
# 2  3668-QPYBK    Male           0          No             No          Yes
# 3  7795-CFOCW    Male           0          No             No           No
# 4  9237-HQITU  Female           0          No             No          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# 0  No phone service             DSL             No          Yes  ...
# 1                No             DSL            Yes           No  ...
# 2                No             DSL            Yes          Yes  ...
# 3  No phone service             DSL            Yes           No  ...
# 4                No     Fiber optic             No           No  ...
#
#   StreamingMovies tenure        Contract PaperlessBilling  \
# ...

# %%
df_crosstab_churn_MesAmes = pd.crosstab(df_churn.Churn, df_churn.MesAmes)

# %%
#calcular os scores
chi_scores_churn_MesAmes = chi2_contingency(df_crosstab_churn_MesAmes)

# %%
scores_churn_MesAmes = pd.Series(chi_scores_churn_MesAmes[0])
pvalues_churn_MesAmes = pd.Series(chi_scores_churn_MesAmes[1])

# %%
df_chi_scores_churn_MesAmes = pd.DataFrame({'Qui2': scores_churn_MesAmes, 'p-value':pvalues_churn_MesAmes})
df_chi_scores_churn_MesAmes
# Out:
#                   Qui2           p-value
# 0 1153.971661109347679 0.000000000000000

# %% [markdown]
# Como o p-value <= 0.5, rejeitamos a h0, ou seja as variaveis não são idependentes

# %% [markdown]
# ## Detecção de Outliers

# %%
df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   Genero            7043 non-null   object
#  2   Mais65anos        7043 non-null   int64
#  3   TemParceiro       7043 non-null   object
#  4   TemDependentes    7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  tenure            7043 non-null   int64
#  15  Contract          7043 non-null   object
# ...

# %%
# Remover Linhas com valores nulos

df_churn.dropna(axis=0, inplace=True)
df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0 to 7042
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7032 non-null   object
#  1   Genero            7032 non-null   object
#  2   Mais65anos        7032 non-null   int64
#  3   TemParceiro       7032 non-null   object
#  4   TemDependentes    7032 non-null   object
#  5   PhoneService      7032 non-null   object
#  6   MultipleLines     7032 non-null   object
#  7   InternetService   7032 non-null   object
#  8   OnlineSecurity    7032 non-null   object
#  9   OnlineBackup      7032 non-null   object
#  10  DeviceProtection  7032 non-null   object
#  11  TechSupport       7032 non-null   object
#  12  StreamingTV       7032 non-null   object
#  13  StreamingMovies   7032 non-null   object
#  14  tenure            7032 non-null   int64
#  15  Contract          7032 non-null   object
# ...

# %%
# Box Plot geral
df_churn['TotalCharges'].plot.box()
# Out:
# <Axes: >

# %%
# Box plot agrupado por contract
df_churn.plot.box(column='TotalCharges', by='Contract')
# Out:
# TotalCharges    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
df_churn_month = df_churn[df_churn.Contract =='Month-to-month']
df_churn_month
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 2     3668-QPYBK    Male           0          No             No          Yes
# 4     9237-HQITU  Female           0          No             No          Yes
# 5     9305-CDSKC  Female           0          No             No          Yes
# 6     1452-KIOVK    Male           0          No            Yes          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7033  9767-FFLEM    Male           0          No             No          Yes
# 7034  0639-TSIQW  Female           0          No             No          Yes
# 7035  8456-QDAVC    Male           0          No             No          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
#
# ...

# %%
df_churn_month.TotalCharges.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Metodo de Tukey - IQR (DISTRIBUIÇÃO NÃO NORMMAL)]
# IQR - Range Interquartil
# IQR = 3o quartil - 1o Quartil
q1_TotalCharges_month = df_churn_month.TotalCharges.quantile(0.25)
q3_TotalCharges_month = df_churn_month.TotalCharges.quantile(0.75)
iqr_TotalCharges_month = q3_TotalCharges_month - q1_TotalCharges_month
iqr_TotalCharges_month
# Out:
# np.float64(1906.4)

# %%
limInf_TotalCharges_month = q1_TotalCharges_month - (iqr_TotalCharges_month * 1.5)
limSup_TotalCharges_month = q3_TotalCharges_month + (iqr_TotalCharges_month * 1.5)
limInf_TotalCharges_month, limSup_TotalCharges_month
# Out:
# (np.float64(-2699.5000000000005), np.float64(4926.1))

# %%
df_churn_month[(df_churn_month.TotalCharges < limInf_TotalCharges_month) |
               (df_churn_month.TotalCharges > limInf_TotalCharges_month) ]
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 2     3668-QPYBK    Male           0          No             No          Yes
# 4     9237-HQITU  Female           0          No             No          Yes
# 5     9305-CDSKC  Female           0          No             No          Yes
# 6     1452-KIOVK    Male           0          No            Yes          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7033  9767-FFLEM    Male           0          No             No          Yes
# 7034  0639-TSIQW  Female           0          No             No          Yes
# 7035  8456-QDAVC    Male           0          No             No          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
#
# ...

# %%
# ZScore (usado para distribuição normal)
# Indica quantos desvios padrões um ponto especifico de dados está distante da média
# zscore = (x - média) / desvio padrão
from scipy.stats import zscore

# %%
z = np.abs(zscore(df_churn_month.TotalCharges))

# %%
z
# Out:
# array([0.83003585, 0.78151294, 0.75455577, ..., 0.07798705, 0.63383722,
#        0.65853247], shape=(3875,))

# %%
df_churn_month[z > 3.0]
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 93    6067-NGCEU  Female           0          No             No          Yes
# 197   6168-YBYNP    Male           0          No             No          Yes
# 339   1343-EHPYB    Male           0         Yes             No          Yes
# 402   0979-PHULV    Male           0         Yes            Yes          Yes
# 445   7752-XUSCI  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 6565  1548-FEHVL    Male           0         Yes             No          Yes
# 6587  7426-GSWPO    Male           1          No             No          Yes
# 6713  4989-LIXVT    Male           1          No             No          Yes
# 7023  1035-IPQPU  Female           1         Yes             No          Yes
# 7034  0639-TSIQW  Female           0          No             No          Yes
#
# ...

# %% [markdown]
# ## Automatizando EDA

# %%
# SweetViz - Abrir no Jupyter Notebook
import sweetviz as sv

# %%
sv_churn_report = sv.analyze(df_churn, target_feat='Churn')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sv_churn_report = sv.analyze(df_churn, target_feat='Churn')
#
# NameError: name 'df_churn' is not defined
